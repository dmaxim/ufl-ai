# %% [markdown]
# <a href="https://colab.research.google.com/github/dmaxim/ufl-ai/blob/main/landscapes_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pathlib

# download training data
train_url = 'https://zenodo.org/record/5512793/files/train.tgz'
train_dir = tf.keras.utils.get_file(origin=train_url, fname='train', untar=True)
train_dir = pathlib.Path(train_dir)

valid_url = 'https://zenodo.org/record/5512793/files/valid.tgz'
valid_dir = tf.keras.utils.get_file(origin=valid_url, fname='valid', untar=True)
valid_dir = pathlib.Path(valid_dir)

train_image_count = len(list(train_dir.glob('*/*.jpg')))
valid_image_count = len(list(valid_dir.glob('*/*.jpg')))
print(train_image_count, valid_image_count)

train_data = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                 image_size=(150,150),
                                                                 batch_size=32)

valid_data = tf.keras.preprocessing.image_dataset_from_directory(valid_dir,
                                                                 image_size=(150, 150),
                                                                 batch_size=32)

print(train_data, valid_data)
# Out:
# Downloading data from https://zenodo.org/record/5512793/files/train.tgz
# 200908942/200908942 [==============================] - 75s 0us/step
# Downloading data from https://zenodo.org/record/5512793/files/valid.tgz
# 42810482/42810482 [==============================] - 17s 0us/step
# 14034 3000
# Found 14034 files belonging to 6 classes.
# Found 3000 files belonging to 6 classes.
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))> <_BatchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# build the model

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=[150,150,3]))
model.add(tf.keras.layers.Conv2D(filters=1, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.softmax))

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)       0
#
#  conv2d_1 (Conv2D)           (None, 148, 148, 1)       28
#
#  flatten_1 (Flatten)         (None, 21904)             0
#
#  dense_1 (Dense)             (None, 6)                 131430
#
# =================================================================
# Total params: 131458 (513.51 KB)
# Trainable params: 131458 (513.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 439/439 [==============================] - 20s 20ms/step - loss: 1.7092 - accuracy: 0.3612 - val_loss: 1.4169 - val_accuracy: 0.4423
# Epoch 2/20
# 439/439 [==============================] - 9s 20ms/step - loss: 1.2950 - accuracy: 0.5028 - val_loss: 1.3273 - val_accuracy: 0.4750
# Epoch 3/20
# 439/439 [==============================] - 9s 21ms/step - loss: 1.1147 - accuracy: 0.5896 - val_loss: 1.2594 - val_accuracy: 0.4970
# Epoch 4/20
# 439/439 [==============================] - 8s 18ms/step - loss: 0.9323 - accuracy: 0.6717 - val_loss: 1.2546 - val_accuracy: 0.5093
# Epoch 5/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.7533 - accuracy: 0.7525 - val_loss: 1.3474 - val_accuracy: 0.4887
# Epoch 6/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.5781 - accuracy: 0.8268 - val_loss: 1.4559 - val_accuracy: 0.4690
# Epoch 7/20
# 439/439 [==============================] - 9s 21ms/step - loss: 0.4327 - accuracy: 0.8820 - val_loss: 1.6576 - val_accuracy: 0.4620
# Epoch 8/20
# 439/439 [==============================] - 8s 18ms/step - loss: 0.3135 - accuracy: 0.9263 - val_loss: 1.8560 - val_accuracy: 0.4410
# Epoch 9/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.2286 - accuracy: 0.9531 - val_loss: 2.0818 - val_accuracy: 0.4397
# Epoch 10/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.1648 - accuracy: 0.9722 - val_loss: 2.2637 - val_accuracy: 0.4537
# Epoch 11/20
# 439/439 [==============================] - 8s 18ms/step - loss: 0.1286 - accuracy: 0.9806 - val_loss: 2.5744 - val_accuracy: 0.4337
# Epoch 12/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.1156 - accuracy: 0.9812 - val_loss: 2.7148 - val_accuracy: 0.4237
# Epoch 13/20
# 439/439 [==============================] - 9s 21ms/step - loss: 0.1028 - accuracy: 0.9829 - val_loss: 2.9451 - val_accuracy: 0.4243
# Epoch 14/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.0913 - accuracy: 0.9846 - val_loss: 3.2260 - val_accuracy: 0.4207
# Epoch 15/20
# 439/439 [==============================] - 8s 17ms/step - loss: 0.0704 - accuracy: 0.9900 - val_loss: 3.3900 - val_accuracy: 0.4180
# Epoch 16/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.0628 - accuracy: 0.9922 - val_loss: 3.4366 - val_accuracy: 0.4203
# Epoch 17/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.0467 - accuracy: 0.9949 - val_loss: 3.5817 - val_accuracy: 0.4187
# Epoch 18/20
# 439/439 [==============================] - 8s 18ms/step - loss: 0.0745 - accuracy: 0.9855 - val_loss: 3.7082 - val_accuracy: 0.4203
# Epoch 19/20
# 439/439 [==============================] - 9s 21ms/step - loss: 0.0879 - accuracy: 0.9803 - val_loss: 3.8074 - val_accuracy: 0.4193
# Epoch 20/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.0566 - accuracy: 0.9893 - val_loss: 4.0000 - val_accuracy: 0.4163

# %%
# Add drop out layer
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=[150,150,3]))
model.add(tf.keras.layers.Conv2D(filters=1, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.Dropout(rate=0.9))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.softmax))

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 150, 150, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 148, 148, 1)       28
#
#  dropout_1 (Dropout)         (None, 148, 148, 1)       0
#
#  flatten_3 (Flatten)         (None, 21904)             0
#
#  dense_3 (Dense)             (None, 6)                 131430
#
# =================================================================
# Total params: 131458 (513.51 KB)
# Trainable params: 131458 (513.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 439/439 [==============================] - 10s 20ms/step - loss: 2.3014 - accuracy: 0.2033 - val_loss: 1.7717 - val_accuracy: 0.2197
# Epoch 2/20
# 439/439 [==============================] - 8s 18ms/step - loss: 1.7706 - accuracy: 0.2217 - val_loss: 1.7566 - val_accuracy: 0.2670
# Epoch 3/20
# 439/439 [==============================] - 8s 19ms/step - loss: 1.7384 - accuracy: 0.2663 - val_loss: 1.7090 - val_accuracy: 0.3197
# Epoch 4/20
# 439/439 [==============================] - 9s 19ms/step - loss: 1.6076 - accuracy: 0.3459 - val_loss: 1.4757 - val_accuracy: 0.3993
# Epoch 5/20
# 439/439 [==============================] - 9s 20ms/step - loss: 1.3906 - accuracy: 0.4428 - val_loss: 1.2716 - val_accuracy: 0.4903
# Epoch 6/20
# 439/439 [==============================] - 9s 21ms/step - loss: 1.2583 - accuracy: 0.5047 - val_loss: 1.2038 - val_accuracy: 0.5207
# Epoch 7/20
# 439/439 [==============================] - 9s 20ms/step - loss: 1.1953 - accuracy: 0.5285 - val_loss: 1.1701 - val_accuracy: 0.5393
# Epoch 8/20
# 439/439 [==============================] - 9s 19ms/step - loss: 1.1491 - accuracy: 0.5478 - val_loss: 1.1376 - val_accuracy: 0.5460
# Epoch 9/20
# 439/439 [==============================] - 12s 27ms/step - loss: 1.1222 - accuracy: 0.5570 - val_loss: 1.1251 - val_accuracy: 0.5533
# Epoch 10/20
# 439/439 [==============================] - 9s 20ms/step - loss: 1.0967 - accuracy: 0.5642 - val_loss: 1.1091 - val_accuracy: 0.5587
# Epoch 11/20
# 439/439 [==============================] - 9s 21ms/step - loss: 1.0815 - accuracy: 0.5753 - val_loss: 1.0989 - val_accuracy: 0.5563
# Epoch 12/20
# 439/439 [==============================] - 8s 18ms/step - loss: 1.0575 - accuracy: 0.5799 - val_loss: 1.1111 - val_accuracy: 0.5543
# Epoch 13/20
# 439/439 [==============================] - 8s 18ms/step - loss: 1.0479 - accuracy: 0.5804 - val_loss: 1.1120 - val_accuracy: 0.5580
# Epoch 14/20
# 439/439 [==============================] - 9s 20ms/step - loss: 1.0329 - accuracy: 0.5882 - val_loss: 1.1235 - val_accuracy: 0.5630
# Epoch 15/20
# 439/439 [==============================] - 9s 20ms/step - loss: 1.0370 - accuracy: 0.5889 - val_loss: 1.0942 - val_accuracy: 0.5647
# Epoch 16/20
# 439/439 [==============================] - 8s 18ms/step - loss: 1.0234 - accuracy: 0.5944 - val_loss: 1.0764 - val_accuracy: 0.5660
# Epoch 17/20
# 439/439 [==============================] - 9s 21ms/step - loss: 1.0022 - accuracy: 0.6050 - val_loss: 1.0739 - val_accuracy: 0.5683
# Epoch 18/20
# 439/439 [==============================] - 9s 20ms/step - loss: 1.0058 - accuracy: 0.6049 - val_loss: 1.0660 - val_accuracy: 0.5727
# Epoch 19/20
# 439/439 [==============================] - 8s 19ms/step - loss: 0.9936 - accuracy: 0.6064 - val_loss: 1.0662 - val_accuracy: 0.5717
# Epoch 20/20
# 439/439 [==============================] - 9s 21ms/step - loss: 0.9768 - accuracy: 0.6102 - val_loss: 1.0891 - val_accuracy: 0.5700

# %%
# Add more filters
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=[150,150,3]))
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.Dropout(rate=0.9))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.softmax))

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 150, 150, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 148, 148, 32)      896
#
#  dropout_3 (Dropout)         (None, 148, 148, 32)      0
#
#  flatten_5 (Flatten)         (None, 700928)            0
#
#  dense_5 (Dense)             (None, 6)                 4205574
#
# =================================================================
# Total params: 4206470 (16.05 MB)
# Trainable params: 4206470 (16.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 439/439 [==============================] - 12s 22ms/step - loss: 1.7462 - accuracy: 0.5999 - val_loss: 0.9141 - val_accuracy: 0.6880
# Epoch 2/20
# 439/439 [==============================] - 12s 27ms/step - loss: 0.7858 - accuracy: 0.7183 - val_loss: 0.8835 - val_accuracy: 0.7090
# Epoch 3/20
# 439/439 [==============================] - 12s 26ms/step - loss: 0.6167 - accuracy: 0.7852 - val_loss: 0.8840 - val_accuracy: 0.7140
# Epoch 4/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0
20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.6359 - accuracy: 0.7756 - val_loss: 0.8697 - val_accuracy: 0.7100
# Epoch 6/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.5929 - accuracy: 0.7909 - val_loss: 0.8411 - val_accuracy: 0.7443
# Epoch 7/20
# 439/439 [==============================] - 11s 26ms/step - loss: 0.5791 - accuracy: 0.7973 - val_loss: 0.8076 - val_accuracy: 0.7423
# Epoch 8/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.5415 - accuracy: 0.8085 - val_loss: 0.8445 - val_accuracy: 0.7503
# Epoch 9/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.5320 - accuracy: 0.8173 - val_loss: 0.8075 - val_accuracy: 0.7487
# Epoch 10/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.5197 - accuracy: 0.8146 - val_loss: 0.8260 - val_accuracy: 0.7603
# Epoch 11/20
# 439/439 [==============================] - 11s 25ms/step - loss: 0.5073 - accuracy: 0.8269 - val_loss: 0.8846 - val_accuracy: 0.7417
# Epoch 12/20
# 439/439 [==============================] - 11s 26ms/step - loss: 0.4781 - accuracy: 0.8309 - val_loss: 0.9250 - val_accuracy: 0.7420
# Epoch 13/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.4780 - accuracy: 0.8318 - val_loss: 0.8671 - val_accuracy: 0.7423
# Epoch 14/20
# 439/439 [==============================] - 10s 23ms/step - loss: 0.4766 - accuracy: 0.8391 - val_loss: 0.9252 - val_accuracy: 0.7377
# Epoch 15/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.4586 - accuracy: 0.8418 - val_loss: 0.9300 - val_accuracy: 0.7560
# Epoch 16/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.4458 - accuracy: 0.8442 - val_loss: 1.0135 - val_accuracy: 0.7360
# Epoch 17/20
# 439/439 [==============================] - 11s 25ms/step - loss: 0.4464 - accuracy: 0.8475 - val_loss: 1.0171 - val_accuracy: 0.7343
# Epoch 18/20
# 439/439 [==============================] - 11s 26ms/step - loss: 0.4314 - accuracy: 0.8538 - val_loss: 0.9464 - val_accuracy: 0.7607
# Epoch 19/20
# 439/439 [==============================] - 10s 24ms/step - loss: 0.4316 - accuracy: 0.8516 - val_loss: 0.9700 - val_accuracy: 0.7430
# Epoch 20/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.4366 - accuracy: 0.8536 - val_loss: 0.9964 - val_accuracy: 0.7463

# %%
# Add convolution-pooling-drop
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=[150,150,3]))
# Module 1
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.MaxPool2D())
model.add(tf.keras.layers.Dropout(rate=0.9))

# Module 2
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.MaxPool2D())
model.add(tf.keras.layers.Dropout(rate=0.9))

# Module 3
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.MaxPool2D())
model.add(tf.keras.layers.Dropout(rate=0.9))

# Module 4
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.MaxPool2D())
model.add(tf.keras.layers.Dropout(rate=0.9))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.softmax))

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_8 (Rescaling)     (None, 150, 150, 3)       0
#
#  conv2d_11 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_5 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 74, 74, 32)        0
#
#  conv2d_12 (Conv2D)          (None, 72, 72, 32)        9248
#
#  max_pooling2d_6 (MaxPoolin  (None, 36, 36, 32)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 36, 36, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 34, 34, 32)        9248
#
#  max_pooling2d_7 (MaxPoolin  (None, 17, 17, 32)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None,
# 439/439 [==============================] - 12s 28ms/step - loss: 1.2131 - accuracy: 0.5016 - val_loss: 2.5601 - val_accuracy: 0.1843
# Epoch 19/20
# 439/439 [==============================] - 12s 28ms/step - loss: 1.2075 - accuracy: 0.4985 - val_loss: 2.5886 - val_accuracy: 0.1843
# Epoch 20/20
# 439/439 [==============================] - 12s 28ms/step - loss: 1.1934 - accuracy: 0.5070 - val_loss: 2.5560 - val_accuracy: 0.1843

# %%
# Add convolution-pooling-without dropout
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=[150,150,3]))
# Module 1
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.MaxPool2D())

# Module 2
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.MaxPool2D())

# Module 3
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.MaxPool2D())

# Module 4
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.MaxPool2D())

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.softmax))

model.summary()


model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_10 (Rescaling)    (None, 150, 150, 3)       0
#
#  conv2d_19 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_13 (MaxPooli  (None, 74, 74, 32)        0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 72, 72, 32)        9248
#
#  max_pooling2d_14 (MaxPooli  (None, 36, 36, 32)        0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 34, 34, 32)        9248
#
#  max_pooling2d_15 (MaxPooli  (None, 17, 17, 32)        0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 15, 15, 32)        9248
#
#  max_pooling2d_16 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  flatten_10 (Flatten)        (None, 1568)              0
#
#  dense_10 (Dense)            (None, 6)                 9414
#
# =================================================================
# Total params: 38054 (148.65 KB)
# Trainable params: 38054 (148.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 439/439 [==============================] - 12s 24ms/step - loss: 1.0550 - accuracy: 0.5906 - val_loss: 0.8779 - val_accuracy: 0.6793
# Epoch 2/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.7324 - accuracy: 0.7294 - val_loss: 0.6576 - val_accuracy: 0.7600
# Epoch 3/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.6207 - accuracy: 0.7756 - val_loss: 0.7782 - val_accuracy: 0.7137
# Epoch 4/20
# 439/439 [==============================] - 11s 25ms/step - loss: 0.5622 - accuracy: 0.8005 - val_loss: 0.6233 - val_accuracy: 0.7753
# Epoch 5/20
# 439/439 [==============================] - 11s 25ms/step - loss: 0.5092 - accuracy: 0.8179 - val_loss: 0.5544 - val_accuracy: 0.7983
# Epoch 6/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.4676 - accuracy: 0.8318 - val_loss: 0.5433 - val_accuracy: 0.7983
# Epoch 7/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.4276 - accuracy: 0.8483 - val_loss: 0.5140 - val_accuracy: 0.8233
# Epoch 8/20
# 439/439 [==============================] - 11s 25ms/step - loss: 0.4105 - accuracy: 0.8519 - val_loss: 0.5535 - val_accuracy: 0.8027
# Epoch 9/20
# 439/439 [==============================] - 10s 22ms/step - loss: 0.3711 - accuracy: 0.8645 - val_loss: 0.5195 - val_accuracy: 0.8290
# Epoch 10/20
# 439/439 [==============================] - 12s 27ms/step - loss: 0.3498 - accuracy: 0.8740 - val_loss: 0.5161 - val_accuracy: 0.8393
# Epoch 11/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.3240 - accuracy: 0.8831 - val_loss: 0.5719 - val_accuracy: 0.8233
# Epoch 12/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.3074 - accuracy: 0.8884 - val_loss: 0.7460 - val_accuracy: 0.7650
# Epoch 13/20
# 439/439 [==============================] - 12s 27ms/step - loss: 0.2758 - accuracy: 0.9007 - val_loss: 0.5826 - val_accuracy: 0.8190
# Epoch 14/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.2521 - accuracy: 0.9101 - val_loss: 0.6210 - val_accuracy: 0.8003
# Epoch 15/20
# 439/439 [==============================] - 11s 25ms/step - loss: 0.2309 - accuracy: 0.9177 - val_loss: 0.6407 - val_accuracy: 0.8157
# Epoch 16/20
# 439/439 [==============================] - 11s 25ms/step - loss: 0.2191 - accuracy: 0.9193 - val_loss: 0.7500 - val_accuracy: 0.7853
# Epoch 17/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.2046 - accuracy: 0.9260 - val_loss: 0.7573 - val_accuracy: 0.8077
# Epoch 18/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.1714 - accuracy: 0.9395 - val_loss: 0.7918 - val_accuracy: 0.8113
# Epoch 19/20
# 439/439 [==============================] - 11s 24ms/step - loss: 0.1597 - accuracy: 0.9439 - val_loss: 0.7834 - val_accuracy: 0.8163
# Epoch 20/20
# 439/439 [==============================] - 11s 25ms/step - loss: 0.1494 - accuracy: 0.9451 - val_loss: 0.8546 - val_accuracy: 0.8073

# %%
# Using MobleNet for transfer learning
import tensorflow as tf

# Downlod pre-trained convolution network -include_top false throw away existing decision layers
base_model = tf.keras.applications.MobileNetV2(input_shape=(150,150,3),
                                               include_top=False,
                                               weights='imagenet')

base_model.trainable = False

base_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 75, 75, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 75, 75, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 75, 75, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 75, 75, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 75, 75, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 75, 75, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 75, 75, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 75, 75, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 75, 75, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 75, 75, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 75, 75, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 77, 77, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 38, 38, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 38, 38, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 38, 38, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 38, 38, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 38, 38, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 38, 38, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 38, 38, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 38, 38, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 38, 38, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 38, 38, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 38, 38, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 38, 38, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 38, 38, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 38, 38, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 38, 38, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 38, 38, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 38, 38, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 39, 39, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 19, 19, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 19, 19, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 19, 19, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 19, 19, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 19, 19, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 19, 19, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 19, 19, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 19, 19, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 19, 19, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 19, 19, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 19, 19, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 19, 19, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 19, 19, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 19, 19, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 19, 19, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 19, 19, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 19, 19, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 19, 19, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 19, 19, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 19, 19, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 19, 19, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 19, 19, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 19, 19, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 19, 19, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 19, 19, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 19, 19, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 21, 21, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 10, 10, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 10, 10, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 10, 10, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 10, 10, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 10, 10, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 10, 10, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 10, 10, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 10, 10, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 10, 10, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 10, 10, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 10, 10, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 10, 10, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 10, 10, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 10, 10, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 10, 10, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 10, 10, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 10, 10, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 10, 10, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 10, 10, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 10, 10, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 10, 10, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 10, 10, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 10, 10, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 10, 10, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 10, 10, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 10, 10, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 10, 10, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 10, 10, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 10, 10, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 10, 10, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 10, 10, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 10, 10, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 10, 10, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 10, 10, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 10, 10, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 10, 10, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 10, 10, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 10, 10, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 10, 10, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 10, 10, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 10, 10, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 10, 10, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 10, 10, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 10, 10, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 10, 10, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 10, 10, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 10, 10, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 10, 10, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 10, 10, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 10, 10, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 10, 10, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 10, 10, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 10, 10, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 10, 10, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 10, 10, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 10, 10, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 10, 10, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 10, 10, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 10, 10, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 10, 10, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 10, 10, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 11, 11, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 5, 5, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 5, 5, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 5, 5, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 5, 5, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 5, 5, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 5, 5, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 5, 5, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 5, 5, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 5, 5, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 5, 5, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 5, 5, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 5, 5, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 5, 5, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 5, 5, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 5, 5, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 5, 5, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 5, 5, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 5, 5, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 5, 5, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 5, 5, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 5, 5, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 5, 5, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 5, 5, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 5, 5, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 5, 5, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 5, 5, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 5, 5, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 5, 5, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 5, 5, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 5, 5, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 5, 5, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 5, 5, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 5, 5, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 5, 5, 1280)           0         ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2257984 (8.61 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
# build complete inference model
model = tf.keras.Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=[150,150,3]))
model.add(base_model)
model.add(tf.keras.layers.MaxPool2D())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.softmax))
model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_13 (Rescaling)    (None, 150, 150, 3)       0
#
#  mobilenetv2_1.00_224 (Func  (None, 5, 5, 1280)        2257984
#  tional)
#
#  max_pooling2d_19 (MaxPooli  (None, 2, 2, 1280)        0
#  ng2D)
#
#  flatten_13 (Flatten)        (None, 5120)              0
#
#  dense_13 (Dense)            (None, 6)                 30726
#
# =================================================================
# Total params: 2288710 (8.73 MB)
# Trainable params: 30726 (120.02 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________
# Epoch 1/20
# 439/439 [==============================] - 21s 41ms/step - loss: 0.6926 - accuracy: 0.8469 - val_loss: 0.6196 - val_accuracy: 0.8737
# Epoch 2/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.4269 - accuracy: 0.9005 - val_loss: 0.6082 - val_accuracy: 0.8790
# Epoch 3/20
# 439/439 [==============================] - 15s 33ms/step - loss: 0.3096 - accuracy: 0.9217 - val_loss: 1.3145 - val_accuracy: 0.8143
# Epoch 4/20
# 439/439 [==============================] - 15s 33ms/step - loss: 0.2635 - accuracy: 0.9340 - val_loss: 0.6973 - val_accuracy: 0.8847
# Epoch 5/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.2302 - accuracy: 0.9418 - val_loss: 0.7129 - val_accuracy: 0.8790
# Epoch 6/20
# 439/439 [==============================] - 15s 35ms/step - loss: 0.2155 - accuracy: 0.9443 - val_loss: 0.8443 - val_accuracy: 0.8707
# Epoch 7/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.1629 - accuracy: 0.9554 - val_loss: 0.7476 - val_accuracy: 0.8837
# Epoch 8/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.1368 - accuracy: 0.9629 - val_loss: 0.7504 - val_accuracy: 0.8927
# Epoch 9/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.1056 - accuracy: 0.9689 - val_loss: 0.8865 - val_accuracy: 0.8830
# Epoch 10/20
# 439/439 [==============================] - 15s 33ms/step - loss: 0.1285 - accuracy: 0.9634 - val_loss: 1.0897 - val_accuracy: 0.8700
# Epoch 11/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.2025 - accuracy: 0.9559 - val_loss: 1.1213 - val_accuracy: 0.8703
# Epoch 12/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.1338 - accuracy: 0.9672 - val_loss: 1.1218 - val_accuracy: 0.8780
# Epoch 13/20
# 439/439 [==============================] - 14s 33ms/step - loss: 0.0992 - accuracy: 0.9745 - val_loss: 1.1902 - val_accuracy: 0.8717
# Epoch 14/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.0852 - accuracy: 0.9773 - val_loss: 1.0069 - val_accuracy: 0.8920
# Epoch 15/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.0813 - accuracy: 0.9795 - val_loss: 1.2751 - val_accuracy: 0.8710
# Epoch 16/20
# 439/439 [==============================] - 14s 33ms/step - loss: 0.0852 - accuracy: 0.9804 - val_loss: 1.4928 - val_accuracy: 0.8650
# Epoch 17/20
# 439/439 [==============================] - 14s 33ms/step - loss: 0.0772 - accuracy: 0.9792 - val_loss: 1.2204 - val_accuracy: 0.8857
# Epoch 18/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.0683 - accuracy: 0.9800 - val_loss: 1.0937 - val_accuracy: 0.8910
# Epoch 19/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.0968 - accuracy: 0.9766 - val_loss: 1.3752 - val_accuracy: 0.8850
# Epoch 20/20
# 439/439 [==============================] - 14s 32ms/step - loss: 0.0838 - accuracy: 0.9797 - val_loss: 1.3072 - val_accuracy: 0.8870

# %%
import tensorflow as tf
import pathlib

# download training data
train_url = 'https://zenodo.org/record/5512793/files/train.tgz'
train_dir = tf.keras.utils.get_file(origin=train_url, fname='train', untar=True)
train_dir = pathlib.Path(train_dir)

# download validation data
valid_url = 'https://zenodo.org/record/5512793/files/valid.tgz'
valid_dir = tf.keras.utils.get_file(origin=valid_url, fname='valid', untar=True)
valid_dir = pathlib.Path(valid_dir)

# print number of training and validation images
train_image_count = len(list(train_dir.glob('*/*.jpg')))
valid_image_count = len(list(valid_dir.glob('*/*.jpg')))
print(train_image_count, valid_image_count)

# package images into tensorflow dataset objects
train_data = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                 image_size=(150,150),
                                                                 batch_size=32)
valid_data = tf.keras.preprocessing.image_dataset_from_directory(valid_dir,
                                                                 image_size=(150,150),
                                                                 batch_size=32)
# print tensorflow dataset objects
print(train_data, valid_data)

# download pre-trained convolution network
base_model = tf.keras.applications.MobileNetV2(input_shape=(150,150,3),
                                               include_top=False,
                                               weights='imagenet')
# turn off training for the base model
base_model.trainable = False

# build complete inference model
model = tf.keras.Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=[150,150,3]))
model.add(tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'))
model.add(tf.keras.layers.experimental.preprocessing.RandomRotation(0.2))
model.add(base_model)
model.add(tf.keras.layers.MaxPool2D())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.softmax))

model.summary()

# compile model
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# fit model
model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# 14034 3000
# Found 14034 files belonging to 6 classes.
# Found 3000 files belonging to 6 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))> <_BatchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_14 (Rescaling)    (None, 150, 150, 3)       0
#
#  random_flip (RandomFlip)    (None, 150, 150, 3)       0
#
#  random_rotation (RandomRot  (None, 150, 150, 3)       0
#  ation)
#
#  mobilenetv2_1.00_224 (Func  (None, 5, 5, 1280)        2257984
#  tional)
#
#  max_pooling2d_20 (MaxPooli  (None, 2, 2, 1280)        0
#  ng2D)
#
#  flatten_14 (Flatten)        (None, 5120)              0
#
#  dense_14 (Dense)            (None, 6)                 30726
#
# =================================================================
# Total params: 2288710 (8.73 MB)
# Trainable params: 30726 (120.02 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________